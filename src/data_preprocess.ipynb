# %%
import pandas as pd
from fuzzywuzzy import process
from collections import defaultdict, Counter

# %%
# Constants
DATA_DIR_RELATIVE_PATH = "../data/"

DATASET_PATH = "../../en.openfoodfacts.org.products.csv"
ISO_COUNTRIES_REGIONS = DATA_DIR_RELATIVE_PATH + "ISO-3166-Countries-with-Regional-Codes.csv"

# %% [markdown]
# ## Process ISO Countries to Regions
# to get the mapping Country -> Region/Sub-region

# %%
def titlecase_to_tag(titlecase: str):
    """
    Convert titlecase to format of tags in our dataset.

    Example:
        titlecase_to_tag("United States") -> "united-states"
    """

    return "-".join(titlecase.lower().split(" "))

# %%
country_region_df = pd.read_csv(
    ISO_COUNTRIES_REGIONS,
    usecols=["name", "region", "sub-region"]
)
country_region_df["country"] = country_region_df["name"].apply(titlecase_to_tag)

# %% [markdown]
# Problem is, for instance **US is written "united-states-of-america" in the mapping, but in OpenFoodFacts dataset it's written "united-states"**.
#
# Let's find the problematic countries names

# %%
country_to_region = {
    row["country"]: (row["region"], row["sub-region"])
    for _, row in country_region_df.iterrows()
}
country_to_region["france"]
# Out:
# ('Europe', 'Western Europe')

# %%
match, score = process.extractOne("foo", ["foobar", "bar", "foooo"])
print(match, score)
# Out:
# foobar 90

# %%
good, bad_to_review, errors = defaultdict(list), defaultdict(list), defaultdict(list)
for country in unique_countries_l:
    try:
        match, score = process.extractOne(country, mapping_dict_keys)
        if score > 90:
            good[country].append(match)
        else:
            bad_to_review[country].append(match)
    except TypeError as e:
        errors[country].append(e)

# %%
good
# Out:
# defaultdict(list,
#             {'libya': ['libya'],
#              'samoa': ['samoa'],
#              'new-caledonia': ['new-caledonia'],
#              'equatorial-guinea': ['equatorial-guinea'],
#              'central-african-republic': ['central-african-republic'],
#              'cameroon': ['cameroon'],
#              'new-zealand': ['new-zealand'],
#              'marshall-islands': ['marshall-islands'],
#              'iraq': ['iraq'],
#              'senegal': ['senegal'],
#              'lebanon': ['lebanon'],
#              'slovenia': ['slovenia'],
#              'peru': ['peru'],
#              'kyrgyzstan': ['kyrgyzstan'],
#              'sierra-leone': ['sierra-leone'],
#              'seychelles': ['seychelles'],
#              'tunisia': ['tunisia'],
#              'honduras': ['honduras'],
#              'brazil': ['brazil'],
#              'martinique': ['martinique'],
#              'luxembourg': ['luxembourg'],
#              'oman': ['oman'],
#              'qatar': ['qatar'],
#              'mauritania': ['mauritania'],
#              'malawi': ['malawi'],
#              'chad': ['chad'],
#              'bahrain': ['bahrain'],
#              'burkina-faso': ['burkina-faso'],
#              'thailand': ['thailand'],
#              'saint-kitts-and-nevis': ['saint-kitts-and-nevis'],
#              'andorra': ['andorra'],
#              'bermuda': ['bermuda'],
#              'madagascar': ['madagascar'],
#              'romania': ['romania'],
#              'dominica': ['dominica'],
#              'mauritius': ['mauritius'],
#              'canada': ['canada'],
#              'cyprus': ['cyprus'],
#              'guatemala': ['guatemala'],
#              'eritrea': ['eritrea'],
#              'somalia': ['somalia'],
#              'belgium': ['belgium'],
#              'ecuador': ['ecuador'],
#              'turkmenistan': ['turkmenistan'],
#              'jordan': ['jordan'],
#              'cote-d-ivoire': ["côte-d'ivoire"],
#              'argentina': ['argentina'],
#              'curacao': ['curaçao'],
#              'angola': ['angola'],
#              'nigeria': ['nigeria'],
#              'chile': ['chile'],
#              'liberia': ['liberia'],
#              'montenegro': ['montenegro'],
#              'bhutan': ['bhutan'],
#              'barbados': ['barbados'],
#              'nicaragua': ['nicaragua'],
#              'sao-tome-and-principe': ['sao-tome-and-principe'],
#              'colombia': ['colombia'],
#              'malaysia': ['malaysia'],
#              'djibouti': ['djibouti'],
#              'uzbekistan': ['uzbekistan'],
#              'ireland': ['ireland'],
#              'bulgaria': ['bulgaria'],
#              'malaysia-中文': ['malaysia'],
#              'cayman-islands': ['cayman-islands'],
#              'nepal': ['nepal'],
#              'romani': ['romania'],
#              'spain': ['spain'],
#              'ireland-uk': ['ireland'],
#              'st-kitts-and-nevis': ['saint-kitts-and-nevis'],
#              'iceland': ['iceland'],
#              'switzerland': ['switzerland'],
#              'guadeloupe': ['guadeloupe'],
#              'indonesia': ['indonesia'],
#              'el-salvador': ['el-salvador'],
#              'hong-kong-粵語': ['hong-kong'],
#              'niger': ['niger'],
#              'algeria': ['algeria'],
#              'zimbabwe': ['zimbabwe'],
#              'afghanistan': ['afghanistan'],
#              'benin': ['benin'],
#              'isle-of-man': ['isle-of-man'],
#              'svalbard-and-jan-mayen': ['svalbard-and-jan-mayen'],
#              'cook-islands': ['cook-islands'],
#              'gambia': ['gambia'],
#              'denmark': ['denmark'],
#              'american-samoa': ['american-samoa'],
#              'suriname': ['suriname'],
#              'bangladesh': ['bangladesh'],
#              'egypt': ['egypt'],
#              'germany': ['germany'],
#              'puerto-rico': ['puerto-rico'],
#              'latvia': ['latvia'],
#              'namibia': ['namibia'],
#              'saint-lucia': ['saint-lucia'],
#              'norway': ['norway'],
#              'comoros': ['comoros'],
#              'gibraltar': ['gibraltar'],
#              'papua-new-guinea': ['papua-new-guinea'],
#              'botswana': ['botswana'],
#              'india': ['india'],
#              'british-virgin-islands': ['virgin-islands-(british)'],
#              'china': ['china'],
#              'kenya': ['kenya'],
#              'finland': ['finland'],
#              'vietnam': ['viet-nam'],
#              'french-polynesia': ['french-polynesia'],
#              'lithuania': ['lithuania'],
#              'vanuatu': ['vanuatu'],
#              'morocco': ['morocco'],
#              'estonia': ['estonia'],
#              'united-states-minor-outlying-islands': ['united-states-minor-outlying-islands'],
#              'state-of-palestine': ['palestine,-state-of'],
#              'christmas-island': ['christmas-island'],
#              'mexico': ['mexico'],
#              'jamaica': ['jamaica'],
#              'democratic-republic-of-the-congo': ['congo,-democratic-republic-of-the'],
#              'cocos-keeling-islands': ['cocos-(keeling)-islands'],
#              'san-marino': ['san-marino'],
#              'monaco': ['monaco'],
#              'tajikistan': ['tajikistan'],
#              'wallis-and-futuna': ['wallis-and-futuna'],
#              'dominican-republic': ['dominican-republic'],
#              'anguilla': ['anguilla'],
#              'cuba': ['cuba'],
#              'zambia': ['zambia'],
#              'sri-lanka': ['sri-lanka'],
#              'uganda': ['uganda'],
#              'malta': ['malta'],
#              'mongolia': ['mongolia'],
#              'guernsey': ['guernsey'],
#              'croatia': ['croatia'],
#              'gabon': ['gabon'],
#              'panama': ['panama'],
#              'paraguay': ['paraguay'],
#              'liechtenstein': ['liechtenstein'],
#              'hong-kong': ['hong-kong'],
#              'pakistan': ['pakistan'],
#              'north-macedonia': ['north-macedonia'],
#              'cambodia': ['cambodia'],
#              'greenland': ['greenland'],
#              'united-arab-emirates': ['united-arab-emirates'],
#              'maldives': ['maldives'],
#              'fiji': ['fiji'],
#              'french-guiana': ['french-guiana'],
#              'guinea': ['guinea'],
#              'turkiye': ['türkiye'],
#              'japan': ['japan'],
#              'france': ['france'],
#              'saudi-arabia': ['saudi-arabia'],
#              'portugal': ['portugal'],
#              'reunion': ['réunion'],
#              'australia': ['australia'],
#              'bosnia-and-herzegovina': ['bosnia-and-herzegovina'],
#              'rwanda': ['rwanda'],
#              'grenada': ['grenada'],
#              'lesotho': ['lesotho'],
#              'mali': ['mali'],
#              'kazakhstan': ['kazakhstan'],
#              'south-sudan': ['south-sudan'],
#              'hungary': ['hungary'],
#              'northern-mariana-islands': ['northern-mariana-islands'],
#              'ghana': ['ghana'],
#              'serbia': ['serbia'],
#              'ethiopia': ['ethiopia'],
#              'kuwait': ['kuwait'],
#              'myanmar': ['myanmar'],
#              'singapore': ['singapore'],
#              'georgia': ['georgia'],
#              'haiti': ['haiti'],
#              'sweden': ['sweden'],
#              'south-africa': ['south-africa'],
#              'sudan': ['sudan'],
#              'aruba': ['aruba'],
#              'guam': ['guam'],
#              'saint-pierre-and-miquelon': ['saint-pierre-and-miquelon'],
#              'jersey': ['jersey'],
#              'faroe-islands': ['faroe-islands'],
#              'mayotte': ['mayotte'],
#              'belarus': ['belarus'],
#              'greece': ['greece'],
#              'montserrat': ['montserrat'],
#              'uruguay': ['uruguay'],
#              'irland': ['ireland'],
#              'guinea-bissau': ['guinea-bissau'],
#              'italy': ['italy'],
#              'albania': ['albania'],
#              'trinidad-and-tobago': ['trinidad-and-tobago'],
#              'poland': ['poland'],
#              'austria': ['austria'],
#              'costa-rica': ['costa-rica'],
#              'mozambique': ['mozambique'],
#              'azerbaijan': ['azerbaijan'],
#              'yemen': ['yemen'],
#              'togo': ['togo'],
#              'burundi': ['burundi'],
#              'guyana': ['guyana'],
#              'solomon-islands': ['solomon-islands'],
#              'aland-islands': ['åland-islands'],
#              'palau': ['palau'],
#              'ukraine': ['ukraine'],
#              'tonga': ['tonga'],
#              'belize': ['belize'],
#              'slovakia': ['slovakia'],
#              'armenia': ['armenia'],
#              'turks-and-caicos-islands': ['turks-and-caicos-islands'],
#              'saint-vincent-and-the-grenadines': ['saint-vincent-and-the-grenadines'],
#              'israel': ['israel'],
#              'timor-leste': ['timor-leste'],
#              'philippines': ['philippines'],
#              'british-indian-ocean-territory': ['british-indian-ocean-territory'],
#              'antigua-and-barbuda': ['antigua-and-barbuda']})

# %% [markdown]
# Avoir les pays (clés du dictionnaire `bad_to_review`) les plus présents dans le dataset

# %%
bad_to_review
# Out:
# defaultdict(list,
#             {'central-america': ['central-african-republic'],
#              'アメリカ合衆国': ['afghanistan'],
#              'francia': ['france'],
#              'republic-of-the-congo': ['congo'],
#              'moldova-roman': ['oman'],
#              'stany-zjednoczone': ['congo'],
#              'polska': ['poland'],
#              'moldova': ['moldova,-republic-of'],
#              'sjedinjene-američke-države': ['sweden'],
#              'liban': ['libya'],
#              'vietnam-tiếng-việt': ['viet-nam'],
#              'mexico-espanol': ['mexico'],
#              'indonesie': ['indonesia'],
#              'puerto-rico-espanol': ['puerto-rico'],
#              'kazakhstan-pyсский': ['kazakhstan'],
#              'mexico-espana': ['mexico'],
#              'etats-unis': ['united-states-of-america'],
#              'china-中文': ['china'],
#              'canada-francais': ['canada'],
#              'on-canada-n6a-4z2': ['canada'],
#              'belgien': ['belize'],
#              'magyarorszag': ['madagascar'],
#              'chins': ['china'],
#              'turkey-turkce': ['türkiye'],
#              'france-spain': ['france'],
#              'espagne': ['spain'],
#              'angleterre': ['angola'],
#              'european-union': ['réunion'],
#              'vancouver-bc-canada': ['canada'],
#              'maroc': ['morocco'],
#              'serbia-srpski': ['serbia'],
#              'franciaorszag': ['france'],
#              'malaysia-bahasa-melayu': ['malaysia'],
#              'dcbsmo': ['samoa'],
#              'russia-русский': ['austria'],
#              'france-francais': ['france'],
#              'latvia-latviešu': ['latvia'],
#              'اوروبا': ['afghanistan'],
#              'unknown': ['réunion'],
#              'hawaii': ['haiti'],
#              'bonaire': ['bonaire,-sint-eustatius-and-saba'],
#              'bulgaria-български': ['bulgaria'],
#              'austria-deutsch': ['austria'],
#              'ecuador-espanol': ['ecuador'],
#              'made-in-canada-from-domestic-and-imported-ingredients': ['antigua-and-barbuda'],
#              'brunei': ['brunei-darussalam'],
#              'uruguay-espanol': ['uruguay'],
#              '日本': ['afghanistan'],
#              'la-reunion': ['réunion'],
#              'northern-ireland': ['ireland'],
#              'cape-verde': ['cabo-verde'],
#              'south-america': ['south-africa'],
#              'wa-usa': ['wallis-and-futuna'],
#              'صنعاء': ['afghanistan'],
#              'dkmdmd': ['heard-island-and-mcdonald-islands'],
#              'sweden-svenska': ['sweden'],
#              'japan-日本語': ['japan'],
#              'schweiz': ['saint-helena,-ascension-and-tristan-da-cunha'],
#              'en-us': ['bonaire,-sint-eustatius-and-saba'],
#              'panama-espanol': ['panama'],
#              'palestinian-territories': ['estonia'],
#              'ascension-island': ['heard-island-and-mcdonald-islands'],
#              'korea-한국어': ["korea,-democratic-people's-republic-of"],
#              'asia': ['austria'],
#              'united-kingdom': ['united-kingdom-of-great-britain-and-northern-ireland'],
#              'czech-republic-čeština': ['congo,-democratic-republic-of-the'],
#              'malaysia-english': ['malaysia'],
#              'nederland': ['netherlands,-kingdom-of-the'],
#              'venezuela': ['venezuela,-bolivarian-republic-of'],
#              'cocoa-horizons': ['réunion'],
#              'francja': ['france'],
#              'england': ['greenland'],
#              'portugal-portugues': ['portugal'],
#              'yqnfyi': ['fiji'],
#              'switzerland-deutsch': ['switzerland'],
#              'product-of-usa-packed-in-canada-imported-by-strong-international-trading-inc-richmond-bc-www-siti-ca': ['bolivia,-plurinational-state-of'],
#              'ukraine-yкраї́нська': ['ukraine'],
#              'germa': ['germany'],
#              'north-korea': ["korea,-democratic-people's-republic-of"],
#              'turkey': ['turkmenistan'],
#              'romania-romană': ['oman'],
#              'united-kingdom-english': ['united-kingdom-of-great-britain-and-northern-ireland'],
#              'dubai': ['cuba'],
#              'اسعدي': ['afghanistan'],
#              'vancouver-canada': ['canada'],
#              'denmark-dansk': ['denmark'],
#              'guatemala-espanol': ['guatemala'],
#              'costa-rica-espanol': ['costa-rica'],
#              'caribbean-netherlands': ['thailand'],
#              'wales': ['palestine,-state-of'],
#              'belgique': ['belgium'],
#              'україна': ['afghanistan'],
#              'south-korea': ["korea,-democratic-people's-republic-of"],
#              'suiza': ['french-polynesia'],
#              'sardinia': ['india'],
#              'botswana-english': ['botswana'],
#              'германия': ['afghanistan'],
#              'united-states': ['united-states-of-america'],
#              'greece-ελληνικά': ['greece'],
#              'lithuania-lietuvių': ['lithuania'],
#              'frankrijk': ['france'],
#              'estonia-eesti': ['estonia'],
#              'frankreich': ['france'],
#              'republica-dominicana-espanol': ['dominica'],
#              'hrvatska': ['haiti'],
#              'natural-calm-canada-5-idleswift-dr-thornhill-on-l4j-1k6': ['australia'],
#              'dom-tom': ['netherlands,-kingdom-of-the'],
#              'zambia-english': ['zambia'],
#              'algerie': ['algeria'],
#              'tanzania': ['tanzania,-united-republic-of'],
#              'ariege': ['argentina'],
#              'netherlands-nederlands': ['thailand'],
#              'kanada': ['canada'],
#              'emirats-arabes-unis': ['united-arab-emirates'],
#              'imported-by-mccormick-canada': ['canada'],
#              'bolivia-espanol': ['bolivia,-plurinational-state-of'],
#              'iran': ['iran,-islamic-republic-of'],
#              'bolivia': ['bolivia,-plurinational-state-of'],
#              'estados-unidos': ['réunion'],
#              'vereinigte-staaten-von-amerika': ['niger'],
#              'trinidad-tobago-english': ['trinidad-and-tobago'],
#              'meksyk': ['jersey'],
#              'belleville-wa': ['belize'],
#              'belgie': ['belize'],
#              'cambodia-english': ['cambodia'],
#              'republic-of-macedonia': ['congo,-democratic-republic-of-the'],
#              'corsica': ['costa-rica'],
#              'reino-unido': ['réunion'],
#              'kunar': ['hungary'],
#              'indonesia-bahasa-indonesia': ['indonesia'],
#              'galmudug': ['guam'],
#              'chint': ['china'],
#              'royaume-uni': ['armenia'],
#              'kelowna-british-columbia-canada': ['canada'],
#              'vereinigtes-konigreich': ['niger'],
#              '대한민국': ['afghanistan'],
#              'taiwan': ['taiwan,-province-of-china'],
#              'jamaica-english': ['jamaica'],
#              'irska': ['iraq'],
#              'europe': ['guadeloupe'],
#              'jan-mayen': ['svalbard-and-jan-mayen'],
#              'iraqi-kurdistan': ['iraq'],
#              'iceland-islenska': ['iceland'],
#              'russia': ['russian-federation'],
#              'philippines-english': ['philippines'],
#              'singapore-english': ['singapore'],
#              'espanha': ['spain'],
#              'aruba-espanol': ['aruba'],
#              'el-salvador-espanol': ['el-salvador'],
#              'middletown-ny-10940-usa': ['chile'],
#              'brazil-en-france': ['brazil'],
#              'worldwide': ['sweden'],
#              'namibia-english': ['namibia'],
#              'japon': ['japan'],
#              'الإمانية': ['afghanistan'],
#              'venezuela-espanol': ['venezuela,-bolivarian-republic-of'],
#              'suisse': ['suriname'],
#              'kosovo': ['comoros'],
#              'sint-eustatius': ['bonaire,-sint-eustatius-and-saba'],
#              'united-states-espanol': ['united-kingdom-of-great-britain-and-northern-ireland'],
#              'mongolia-монгол-хэл': ['mongolia'],
#              'prepared-for-siwin-foods-edmonton-alberta-t6b-3v2': ['algeria'],
#              'cyprus-ελληνικά': ['cyprus'],
#              'armenia-pyсский': ['armenia'],
#              'francuska': ['france'],
#              'south-africa-english': ['south-africa'],
#              'irlande': ['ireland'],
#              'international': ['bolivia,-plurinational-state-of'],
#              'sverige': ['serbia'],
#              'nicaragua-espanol': ['nicaragua'],
#              'ελλάδα': ['afghanistan'],
#              'saint-martin': ['saint-martin-(french-part)'],
#              'soviet-union': ['réunion'],
#              'slovak-republic-slovenčina': ['slovenia'],
#              'slovenia-slovene': ['slovenia'],
#              'hungary-magyar': ['hungary'],
#              'ireland-english': ['ireland'],
#              'the-bahamas': ['bahamas'],
#              'norway-norsk': ['norway'],
#              'united-kingdom-ireland': ['ireland'],
#              'syria': ['syrian-arab-republic'],
#              'india-english': ['india'],
#              'spanien': ['spain'],
#              'njemačka': ['macao'],
#              'ghana-english': ['ghana'],
#              'belgica': ['belgium'],
#              'česko': ['micronesia,-federated-states-of'],
#              'argentina-espanol': ['argentina'],
#              'belgium-nederlands': ['belgium'],
#              'swaziland': ['thailand'],
#              'london': ['lebanon'],
#              'british-columbia': ['british-indian-ocean-territory'],
#              'lebanon-english': ['lebanon'],
#              'west-africa': ['south-africa'],
#              'azerbaijan-русский': ['azerbaijan'],
#              'belgium-francais': ['belgium'],
#              'made-in-the-u-k-ni': ['congo,-democratic-republic-of-the'],
#              'macau': ['macao'],
#              'middle-east-africa': ['south-africa'],
#              'lesotho-english': ['lesotho'],
#              'canada-english': ['canada'],
#              'finland-suomi': ['finland'],
#              'フランス': ['afghanistan'],
#              'republika-srpska': ['syrian-arab-republic'],
#              'brazil-portugues': ['brazil'],
#              'spain-espanol': ['spain'],
#              'deutschland': ['chad'],
#              'bosnia-i-hercegovina-bosnian': ['bosnia-and-herzegovina'],
#              'st-vincent-and-grenadines': ['saint-vincent-and-the-grenadines'],
#              'macau-中文': ['macao'],
#              'allemagne': ['oman'],
#              'luxemburgo': ['luxembourg'],
#              'honduras-espanol': ['honduras'],
#              'laos': ['barbados'],
#              'scotland': ['poland'],
#              'ישראל': ['afghanistan'],
#              'اليمن-عمان-السعوديه': ['isle-of-man'],
#              'thailand-ไทย': ['thailand'],
#              'benelux': ['belarus'],
#              'stati-uniti-d-america': ["côte-d'ivoire"],
#              'カナダ': ['afghanistan'],
#              'asia-pacific': ['haiti'],
#              'ประเทศไทย-thai': ['thailand'],
#              'world': ['jordan'],
#              'kyrgyzstan-русский': ['kyrgyzstan'],
#              'нидерланды': ['afghanistan'],
#              'poland-polski': ['poland'],
#              'czech-republic': ['central-african-republic'],
#              'netherlands': ['netherlands,-kingdom-of-the'],
#              'marruecos': ['macao'],
#              'franca': ['france'],
#              'vatican-city': ['latvia'],
#              'israel-עברית': ['israel'],
#              'germany-deutsch': ['germany'],
#              'switzerland-francais': ['switzerland'],
#              'peru-espanol': ['peru'],
#              'north-macedonia-македонски-јазик': ['north-macedonia'],
#              'united-states-english': ['united-kingdom-of-great-britain-and-northern-ireland'],
#              'angle': ['angola'],
#              'swaziland-english': ['thailand'],
#              'francia-espana': ['france'],
#              'sint-maarten': ['sint-maarten-(dutch-part)'],
#              'taiwan-中文': ['taiwan,-province-of-china'],
#              'italy-italiano': ['italy'],
#              'السعودية': ['afghanistan'],
#              'alemania': ['albania'],
#              'coquitlam-bc': ['costa-rica'],
#              'en': ['argentina'],
#              'bc-canada': ['canada'],
#              'surrey-bc-canada': ['canada'],
#              'belarus-pyсский': ['belarus'],
#              'australia-english': ['australia'],
#              'virgin-islands-of-the-united-states': ['åland-islands'],
#              'yugoslavia': ['latvia'],
#              'netherlands-en-france': ['france'],
#              'niemcy': ['niue'],
#              'east-germany': ['germany'],
#              'maine': ['san-marino'],
#              'croatia-hrvatski': ['croatia'],
#              'indian-subcontinent': ['india'],
#              'chile-espanol': ['chile'],
#              'الاردن': ['afghanistan'],
#              'georgia-ქართული': ['georgia'],
#              'mexique': ['niue'],
#              'new-zealand-english': ['new-zealand'],
#              'serbien': ['serbia'],
#              'المغرب': ['afghanistan'],
#              'švicarska': ['nicaragua'],
#              'middle-east': ['chile'],
#              'paraguay-espanol': ['paraguay'],
#              'colombia-espanol': ['colombia'],
#              'جميع-البلدان': ['holy-see'],
#              'niederlande': ['niue'],
#              'cambodia-ភាសាខ្មែរ': ['cambodia'],
#              'bellingham-wa-usa': ['guam']})

# %%
errors
# Out:
# defaultdict(list,
#             {nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")],
#              nan: [TypeError("expected string or bytes-like object, got 'float'")]})

# %%
sum(len(v) for k, v in good.items()) + sum(len(v) for k, v in bad_to_review.items()) + sum(len(v) for k, v in errors.items())
# Out:
# 548

# %%
from fuzzywuzzy import process

unique_countries_l = list(set(df.explode("processed_countries")["processed_countries"]))

# Find the best match for each country
def fuzzy_match_country(country, choices):
    match, score = process.extractOne(country, choices)
    return match if score > 80 else None  # Use match only if confidence is high

# Apply fuzzy matching
mapping_dict_keys = list(country_to_region.keys())
for country in unique_countries_l:
    try:
        if fuzzy_match_country(country, mapping_dict_keys):
            print(f"{country=} {match=}")
    except TypeError as e:
        print(f"{e}: {country}")
# Out:
# country='central-america' match='foobar'
# country='libya' match='foobar'
# country='republic-of-the-congo' match='foobar'
# country='samoa' match='foobar'
# country='new-caledonia' match='foobar'
# country='moldova-roman' match='foobar'
# country='equatorial-guinea' match='foobar'
# country='moldova' match='foobar'
# country='central-african-republic' match='foobar'
# country='mexico-espanol' match='foobar'
# country='cameroon' match='foobar'
# country='new-zealand' match='foobar'
# country='indonesie' match='foobar'
# country='puerto-rico-espanol' match='foobar'
# country='marshall-islands' match='foobar'
# country='kazakhstan-pyсский' match='foobar'
# country='mexico-espana' match='foobar'
# country='iraq' match='foobar'
# country='senegal' match='foobar'
# country='lebanon' match='foobar'
# country='china-中文' match='foobar'
# country='canada-francais' match='foobar'
# country='on-canada-n6a-4z2' match='foobar'
# country='slovenia' match='foobar'
# country='peru' match='foobar'
# country='kyrgyzstan' match='foobar'
# country='sierra-leone' match='foobar'
# country='seychelles' match='foobar'
# country='tunisia' match='foobar'
# country='honduras' match='foobar'
# expected string or bytes-like object, got 'float': nan
# country='france-spain' match='foobar'
# country='brazil' match='foobar'
# expected string or bytes-like object, got 'float': nan
# country='vancouver-bc-canada' match='foobar'
# country='martinique' match='foobar'
# country='luxembourg' match='foobar'
# country='oman' match='foobar'
# country='serbia-srpski' match='foobar'
# country='qatar' match='foobar'
# country='malaysia-bahasa-melayu' match='foobar'
# country='mauritania' match='foobar'
# country='france-francais' match='foobar'
# country='latvia-latviešu' match='foobar'
# country='malawi' match='foobar'
# country='bonaire' match='foobar'
# country='bulgaria-български' match='foobar'
# country='austria-deutsch' match='foobar'
# country='ecuador-espanol' match='foobar'
# country='made-in-canada-from-domestic-and-imported-ingredients' match='foobar'
# country='brunei' match='foobar'
# country='uruguay-espanol' match='foobar'
# country='northern-ireland' match='foobar'
# country='south-america' match='foobar'
# country='chad' match='foobar'
# country='bahrain' match='foobar'
# country='burkina-faso' match='foobar'
# country='thailand' match='foobar'
# country='saint-kitts-and-nevis' match='foobar'
# country='andorra' match='foobar'
# country='bermuda' match='foobar'
# country='madagascar' match='foobar'
# country='sweden-svenska' match='foobar'
# country='romania' match='foobar'
# country='japan-日本語' match='foobar'
# country='dominica' match='foobar'
# country='mauritius' match='foobar'
# country='canada' match='foobar'
# country='cyprus' match='foobar'
# country='guatemala' match='foobar'
# country='panama-espanol' match='foobar'
# country='ascension-island' match='foobar'
# country='eritrea' match='foobar'
# country='somalia' match='foobar'
# country='korea-한국어' match='foobar'
# country='belgium' match='foobar'
# country='united-kingdom' match='foobar'
# country='czech-republic-čeština' match='foobar'
# country='malaysia-english' match='foobar'
# country='ecuador' match='foobar'
# country='venezuela' match='foobar'
# country='turkmenistan' match='foobar'
# country='portugal-portugues' match='foobar'
# country='jordan' match='foobar'
# country='switzerland-deutsch' match='foobar'
# expected string or bytes-like object, got 'float': nan
# country='cote-d-ivoire' match='foobar'
# country='product-of-usa-packed-in-canada-imported-by-strong-international-trading-inc-richmond-bc-www-siti-ca' match='foobar'
# country='argentina' match='foobar'
# country='ukraine-yкраї́нська' match='foobar'
# country='germa' match='foobar'
# country='curacao' match='foobar'
# country='north-korea' match='foobar'
# country='angola' match='foobar'
# country='nigeria' match='foobar'
# country='romania-romană' match='foobar'
# country='united-kingdom-english' match='foobar'
# country='chile' match='foobar'
# country='liberia' match='foobar'
# country='montenegro' match='foobar'
# country='bhutan' match='foobar'
# country='vancouver-canada' match='foobar'
# country='denmark-dansk' match='foobar'
# country='barbados' match='foobar'
# country='guatemala-espanol' match='foobar'
# country='costa-rica-espanol' match='foobar'
# country='nicaragua' match='foobar'
# country='sao-tome-and-principe' match='foobar'
# country='colombia' match='foobar'
# country='malaysia' match='foobar'
# country='south-korea' match='foobar'
# country='botswana-english' match='foobar'
# country='united-states' match='foobar'
# country='djibouti' match='foobar'
# country='greece-ελληνικά' match='foobar'
# country='lithuania-lietuvių' match='foobar'
# country='uzbekistan' match='foobar'
# country='estonia-eesti' match='foobar'
# country='ireland' match='foobar'
# country='bulgaria' match='foobar'
# country='republica-dominicana-espanol' match='foobar'
# country='malaysia-中文' match='foobar'
# country='cayman-islands' match='foobar'
# country='nepal' match='foobar'
# country='romani' match='foobar'
# country='spain' match='foobar'
# country='zambia-english' match='foobar'
# country='ireland-uk' match='foobar'
# country='st-kitts-and-nevis' match='foobar'
# country='iceland' match='foobar'
# country='algerie' match='foobar'
# country='tanzania' match='foobar'
# country='switzerland' match='foobar'
# country='kanada' match='foobar'
# country='guadeloupe' match='foobar'
# country='imported-by-mccormick-canada' match='foobar'
# country='bolivia-espanol' match='foobar'
# country='indonesia' match='foobar'
# country='iran' match='foobar'
# country='bolivia' match='foobar'
# country='trinidad-tobago-english' match='foobar'
# country='el-salvador' match='foobar'
# country='hong-kong-粵語' match='foobar'
# country='belgie' match='foobar'
# country='cambodia-english' match='foobar'
# country='republic-of-macedonia' match='foobar'
# country='niger' match='foobar'
# country='algeria' match='foobar'
# country='zimbabwe' match='foobar'
# country='afghanistan' match='foobar'
# country='benin' match='foobar'
# country='indonesia-bahasa-indonesia' match='foobar'
# country='isle-of-man' match='foobar'
# country='kelowna-british-columbia-canada' match='foobar'
# country='svalbard-and-jan-mayen' match='foobar'
# country='cook-islands' match='foobar'
# country='taiwan' match='foobar'
# country='gambia' match='foobar'
# country='denmark' match='foobar'
# country='jamaica-english' match='foobar'
# country='american-samoa' match='foobar'
# country='jan-mayen' match='foobar'
# country='iraqi-kurdistan' match='foobar'
# country='suriname' match='foobar'
# country='bangladesh' match='foobar'
# country='iceland-islenska' match='foobar'
# country='egypt' match='foobar'
# country='germany' match='foobar'
# country='russia' match='foobar'
# country='philippines-english' match='foobar'
# country='puerto-rico' match='foobar'
# country='latvia' match='foobar'
# country='singapore-english' match='foobar'
# country='namibia' match='foobar'
# country='saint-lucia' match='foobar'
# country='norway' match='foobar'
# country='aruba-espanol' match='foobar'
# country='comoros' match='foobar'
# country='el-salvador-espanol' match='foobar'
# country='brazil-en-france' match='foobar'
# country='namibia-english' match='foobar'
# country='gibraltar' match='foobar'
# country='papua-new-guinea' match='foobar'
# country='botswana' match='foobar'
# country='india' match='foobar'
# country='british-virgin-islands' match='foobar'
# country='china' match='foobar'
# country='kenya' match='foobar'
# country='venezuela-espanol' match='foobar'
# country='sint-eustatius' match='foobar'
# country='united-states-espanol' match='foobar'
# country='mongolia-монгол-хэл' match='foobar'
# country='finland' match='foobar'
# country='vietnam' match='foobar'
# country='cyprus-ελληνικά' match='foobar'
# country='french-polynesia' match='foobar'
# country='lithuania' match='foobar'
# country='armenia-pyсский' match='foobar'
# country='vanuatu' match='foobar'
# country='morocco' match='foobar'
# country='estonia' match='foobar'
# country='south-africa-english' match='foobar'
# country='united-states-minor-outlying-islands' match='foobar'
# country='irlande' match='foobar'
# country='nicaragua-espanol' match='foobar'
# country='state-of-palestine' match='foobar'
# country='christmas-island' match='foobar'
# country='mexico' match='foobar'
# country='saint-martin' match='foobar'
# country='jamaica' match='foobar'
# country='democratic-republic-of-the-congo' match='foobar'
# country='cocos-keeling-islands' match='foobar'
# country='slovenia-slovene' match='foobar'
# country='san-marino' match='foobar'
# country='hungary-magyar' match='foobar'
# country='ireland-english' match='foobar'
# country='the-bahamas' match='foobar'
# country='norway-norsk' match='foobar'
# country='monaco' match='foobar'
# country='united-kingdom-ireland' match='foobar'
# country='syria' match='foobar'
# country='tajikistan' match='foobar'
# country='india-english' match='foobar'
# country='wallis-and-futuna' match='foobar'
# country='spanien' match='foobar'
# country='ghana-english' match='foobar'
# country='dominican-republic' match='foobar'
# country='anguilla' match='foobar'
# country='argentina-espanol' match='foobar'
# country='belgium-nederlands' match='foobar'
# country='cuba' match='foobar'
# country='zambia' match='foobar'
# country='sri-lanka' match='foobar'
# country='uganda' match='foobar'
# country='malta' match='foobar'
# country='mongolia' match='foobar'
# country='guernsey' match='foobar'
# country='croatia' match='foobar'
# country='gabon' match='foobar'
# country='british-columbia' match='foobar'
# country='panama' match='foobar'
# country='paraguay' match='foobar'
# country='liechtenstein' match='foobar'
# country='lebanon-english' match='foobar'
# country='hong-kong' match='foobar'
# country='azerbaijan-русский' match='foobar'
# country='pakistan' match='foobar'
# country='belgium-francais' match='foobar'
# country='north-macedonia' match='foobar'
# country='cambodia' match='foobar'
# country='made-in-the-u-k-ni' match='foobar'
# country='middle-east-africa' match='foobar'
# country='greenland' match='foobar'
# country='united-arab-emirates' match='foobar'
# country='lesotho-english' match='foobar'
# country='maldives' match='foobar'
# country='canada-english' match='foobar'
# country='finland-suomi' match='foobar'
# country='brazil-portugues' match='foobar'
# country='fiji' match='foobar'
# country='spain-espanol' match='foobar'
# country='french-guiana' match='foobar'
# country='guinea' match='foobar'
# country='turkiye' match='foobar'
# country='st-vincent-and-grenadines' match='foobar'
# country='japan' match='foobar'
# country='luxemburgo' match='foobar'
# country='france' match='foobar'
# country='honduras-espanol' match='foobar'
# country='saudi-arabia' match='foobar'
# country='portugal' match='foobar'
# country='reunion' match='foobar'
# country='thailand-ไทย' match='foobar'
# country='australia' match='foobar'
# country='bosnia-and-herzegovina' match='foobar'
# country='rwanda' match='foobar'
# expected string or bytes-like object, got 'float': nan
# country='stati-uniti-d-america' match='foobar'
# country='grenada' match='foobar'
# country='lesotho' match='foobar'
# country='mali' match='foobar'
# country='kazakhstan' match='foobar'
# expected string or bytes-like object, got 'float': nan
# country='south-sudan' match='foobar'
# country='hungary' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='northern-mariana-islands' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='ghana' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='serbia' match='foobar'
# country='ethiopia' match='foobar'
# country='kuwait' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='kyrgyzstan-русский' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='poland-polski' match='foobar'
# country='myanmar' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='czech-republic' match='foobar'
# country='singapore' match='foobar'
# country='netherlands' match='foobar'
# country='georgia' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='haiti' match='foobar'
# country='franca' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='sweden' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='south-africa' match='foobar'
# country='sudan' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='israel-עברית' match='foobar'
# expected string or bytes-like object, got 'float': nan
# country='germany-deutsch' match='foobar'
# expected string or bytes-like object, got 'float': nan
# country='switzerland-francais' match='foobar'
# country='aruba' match='foobar'
# expected string or bytes-like object, got 'float': nan
# country='guam' match='foobar'
# country='saint-pierre-and-miquelon' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='jersey' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='faroe-islands' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='peru-espanol' match='foobar'
# country='mayotte' match='foobar'
# expected string or bytes-like object, got 'float': nan
# country='belarus' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='north-macedonia-македонски-јазик' match='foobar'
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# expected string or bytes-like object, got 'float': nan
# country='united-states-english' match='foobar'
# country='greece' match='foobar'
# expected string or bytes-like object, got 'float': nan
# country='montserrat' match='foobar'
# country='uruguay' match='foobar'
# country='irland' match='foobar'
# country='guinea-bissau' match='foobar'
# country='italy' match='foobar'
# country='albania' match='foobar'
# country='sint-maarten' match='foobar'
# country='trinidad-and-tobago' match='foobar'
# country='taiwan-中文' match='foobar'
# country='poland' match='foobar'
# country='italy-italiano' match='foobar'
# country='austria' match='foobar'
# country='costa-rica' match='foobar'
# country='mozambique' match='foobar'
# country='azerbaijan' match='foobar'
# country='en' match='foobar'
# country='yemen' match='foobar'
# country='togo' match='foobar'
# country='bc-canada' match='foobar'
# country='surrey-bc-canada' match='foobar'
# country='burundi' match='foobar'
# country='belarus-pyсский' match='foobar'
# country='australia-english' match='foobar'
# country='guyana' match='foobar'
# country='solomon-islands' match='foobar'
# country='virgin-islands-of-the-united-states' match='foobar'
# country='aland-islands' match='foobar'
# country='yugoslavia' match='foobar'
# country='palau' match='foobar'
# country='netherlands-en-france' match='foobar'
# country='ukraine' match='foobar'
# country='east-germany' match='foobar'
# country='croatia-hrvatski' match='foobar'
# country='tonga' match='foobar'
# country='belize' match='foobar'
# country='slovakia' match='foobar'
# country='indian-subcontinent' match='foobar'
# country='armenia' match='foobar'
# country='turks-and-caicos-islands' match='foobar'
# country='chile-espanol' match='foobar'
# country='saint-vincent-and-the-grenadines' match='foobar'
# expected string or bytes-like object, got 'float': nan
# country='georgia-ქართული' match='foobar'
# country='israel' match='foobar'
# country='new-zealand-english' match='foobar'
# country='timor-leste' match='foobar'
# country='philippines' match='foobar'
# country='paraguay-espanol' match='foobar'
# country='british-indian-ocean-territory' match='foobar'
# country='colombia-espanol' match='foobar'
# country='antigua-and-barbuda' match='foobar'
# country='cambodia-ភាសាខ្មែរ' match='foobar'

# %%
def fuzzy_match_country(country, choices):
    match, score = process.extractOne(country, choices)
    return match if score > 80 else None  # Use match only if confidence is high

# %%
fuzzy_match_country("saint-yrieix,france", )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 fuzzy_match_country("saint-yrieix,france", )
#
# TypeError: fuzzy_match_country() missing 1 required positional argument: 'choices'

# %%
len(unique_countries_l)
# Out:
# 548

# %%
from collections import Counter, defaultdict

namecut_l = country_region_df["name"].map(lambda name: name[:10])
c = Counter(namecut_l)
d = defaultdict(list)
for k, v in c.items():
    if v > 1:
        d[v].append(k)
d
# Out:
# defaultdict(list, {2: ['United Sta', 'Virgin Isl']})

# %%
country_region_df[country_region_df["name"].map(lambda name: name[:6] in ("United", "Virgin"))]
# Out:
#                                                   name    region  \
# 233                               United Arab Emirates      Asia
# 234  United Kingdom of Great Britain and Northern I...    Europe
# 235                           United States of America  Americas
# 236               United States Minor Outlying Islands   Oceania
# 242                           Virgin Islands (British)  Americas
# 243                              Virgin Islands (U.S.)  Americas
#
#                           sub-region  \
# 233                     Western Asia
# 234                  Northern Europe
# 235                 Northern America
# 236                       Micronesia
# 242  Latin America and the Caribbean
# 243  Latin America and the Caribbean
#
#                                                country
# 233                               united-arab-emirates
# 234  united-kingdom-of-great-britain-and-northern-i...
# 235                           united-states-of-america
# 236               united-states-minor-outlying-islands
# 242                           virgin-islands-(british)
# 243                              virgin-islands-(u.s.)

# %% [markdown]
# Let's correct the mapping of those countries accordingly to OpenFoodFacts data:

# %%
# Manual mapping for known discrepancies
name_corrections = {
    "united-states-of-america": "united-states",
}

# Function to map or standardize country names
def standardize_country_name(country, corrections):
    return corrections.get(country, country)  # Use corrected name if it exists, else the original

# Apply the mapping
country_to_region["country"] = country_to_region["country"].apply(lambda x: standardize_country_name(x, name_corrections))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 11
#       8     return corrections.get(country, country)  # Use corrected name if it exists, else the original
#      10 # Apply the mapping
# ---> 11 country_to_region["country"] = country_to_region["country"].apply(lambda x: standardize_country_name(x, name_corrections))
#
# KeyError: 'country'

# %%
country_to_region
# Out:
# {'afghanistan': ('Asia', 'Southern Asia'),
#  'åland-islands': ('Europe', 'Northern Europe'),
#  'albania': ('Europe', 'Southern Europe'),
#  'algeria': ('Africa', 'Northern Africa'),
#  'american-samoa': ('Oceania', 'Polynesia'),
#  'andorra': ('Europe', 'Southern Europe'),
#  'angola': ('Africa', 'Sub-Saharan Africa'),
#  'anguilla': ('Americas', 'Latin America and the Caribbean'),
#  'antarctica': (nan, nan),
#  'antigua-and-barbuda': ('Americas', 'Latin America and the Caribbean'),
#  'argentina': ('Americas', 'Latin America and the Caribbean'),
#  'armenia': ('Asia', 'Western Asia'),
#  'aruba': ('Americas', 'Latin America and the Caribbean'),
#  'australia': ('Oceania', 'Australia and New Zealand'),
#  'austria': ('Europe', 'Western Europe'),
#  'azerbaijan': ('Asia', 'Western Asia'),
#  'bahamas': ('Americas', 'Latin America and the Caribbean'),
#  'bahrain': ('Asia', 'Western Asia'),
#  'bangladesh': ('Asia', 'Southern Asia'),
#  'barbados': ('Americas', 'Latin America and the Caribbean'),
#  'belarus': ('Europe', 'Eastern Europe'),
#  'belgium': ('Europe', 'Western Europe'),
#  'belize': ('Americas', 'Latin America and the Caribbean'),
#  'benin': ('Africa', 'Sub-Saharan Africa'),
#  'bermuda': ('Americas', 'Northern America'),
#  'bhutan': ('Asia', 'Southern Asia'),
#  'bolivia,-plurinational-state-of': ('Americas',
#   'Latin America and the Caribbean'),
#  'bonaire,-sint-eustatius-and-saba': ('Americas',
#   'Latin America and the Caribbean'),
#  'bosnia-and-herzegovina': ('Europe', 'Southern Europe'),
#  'botswana': ('Africa', 'Sub-Saharan Africa'),
#  'bouvet-island': ('Americas', 'Latin America and the Caribbean'),
#  'brazil': ('Americas', 'Latin America and the Caribbean'),
#  'british-indian-ocean-territory': ('Africa', 'Sub-Saharan Africa'),
#  'brunei-darussalam': ('Asia', 'South-eastern Asia'),
#  'bulgaria': ('Europe', 'Eastern Europe'),
#  'burkina-faso': ('Africa', 'Sub-Saharan Africa'),
#  'burundi': ('Africa', 'Sub-Saharan Africa'),
#  'cabo-verde': ('Africa', 'Sub-Saharan Africa'),
#  'cambodia': ('Asia', 'South-eastern Asia'),
#  'cameroon': ('Africa', 'Sub-Saharan Africa'),
#  'canada': ('Americas', 'Northern America'),
#  'cayman-islands': ('Americas', 'Latin America and the Caribbean'),
#  'central-african-republic': ('Africa', 'Sub-Saharan Africa'),
#  'chad': ('Africa', 'Sub-Saharan Africa'),
#  'chile': ('Americas', 'Latin America and the Caribbean'),
#  'china': ('Asia', 'Eastern Asia'),
#  'christmas-island': ('Oceania', 'Australia and New Zealand'),
#  'cocos-(keeling)-islands': ('Oceania', 'Australia and New Zealand'),
#  'colombia': ('Americas', 'Latin America and the Caribbean'),
#  'comoros': ('Africa', 'Sub-Saharan Africa'),
#  'congo': ('Africa', 'Sub-Saharan Africa'),
#  'congo,-democratic-republic-of-the': ('Africa', 'Sub-Saharan Africa'),
#  'cook-islands': ('Oceania', 'Polynesia'),
#  'costa-rica': ('Americas', 'Latin America and the Caribbean'),
#  "côte-d'ivoire": ('Africa', 'Sub-Saharan Africa'),
#  'croatia': ('Europe', 'Southern Europe'),
#  'cuba': ('Americas', 'Latin America and the Caribbean'),
#  'curaçao': ('Americas', 'Latin America and the Caribbean'),
#  'cyprus': ('Asia', 'Western Asia'),
#  'czechia': ('Europe', 'Eastern Europe'),
#  'denmark': ('Europe', 'Northern Europe'),
#  'djibouti': ('Africa', 'Sub-Saharan Africa'),
#  'dominica': ('Americas', 'Latin America and the Caribbean'),
#  'dominican-republic': ('Americas', 'Latin America and the Caribbean'),
#  'ecuador': ('Americas', 'Latin America and the Caribbean'),
#  'egypt': ('Africa', 'Northern Africa'),
#  'el-salvador': ('Americas', 'Latin America and the Caribbean'),
#  'equatorial-guinea': ('Africa', 'Sub-Saharan Africa'),
#  'eritrea': ('Africa', 'Sub-Saharan Africa'),
#  'estonia': ('Europe', 'Northern Europe'),
#  'eswatini': ('Africa', 'Sub-Saharan Africa'),
#  'ethiopia': ('Africa', 'Sub-Saharan Africa'),
#  'falkland-islands-(malvinas)': ('Americas',
#   'Latin America and the Caribbean'),
#  'faroe-islands': ('Europe', 'Northern Europe'),
#  'fiji': ('Oceania', 'Melanesia'),
#  'finland': ('Europe', 'Northern Europe'),
#  'france': ('Europe', 'Western Europe'),
#  'french-guiana': ('Americas', 'Latin America and the Caribbean'),
#  'french-polynesia': ('Oceania', 'Polynesia'),
#  'french-southern-territories': ('Africa', 'Sub-Saharan Africa'),
#  'gabon': ('Africa', 'Sub-Saharan Africa'),
#  'gambia': ('Africa', 'Sub-Saharan Africa'),
#  'georgia': ('Asia', 'Western Asia'),
#  'germany': ('Europe', 'Western Europe'),
#  'ghana': ('Africa', 'Sub-Saharan Africa'),
#  'gibraltar': ('Europe', 'Southern Europe'),
#  'greece': ('Europe', 'Southern Europe'),
#  'greenland': ('Americas', 'Northern America'),
#  'grenada': ('Americas', 'Latin America and the Caribbean'),
#  'guadeloupe': ('Americas', 'Latin America and the Caribbean'),
#  'guam': ('Oceania', 'Micronesia'),
#  'guatemala': ('Americas', 'Latin America and the Caribbean'),
#  'guernsey': ('Europe', 'Northern Europe'),
#  'guinea': ('Africa', 'Sub-Saharan Africa'),
#  'guinea-bissau': ('Africa', 'Sub-Saharan Africa'),
#  'guyana': ('Americas', 'Latin America and the Caribbean'),
#  'haiti': ('Americas', 'Latin America and the Caribbean'),
#  'heard-island-and-mcdonald-islands': ('Oceania', 'Australia and New Zealand'),
#  'holy-see': ('Europe', 'Southern Europe'),
#  'honduras': ('Americas', 'Latin America and the Caribbean'),
#  'hong-kong': ('Asia', 'Eastern Asia'),
#  'hungary': ('Europe', 'Eastern Europe'),
#  'iceland': ('Europe', 'Northern Europe'),
#  'india': ('Asia', 'Southern Asia'),
#  'indonesia': ('Asia', 'South-eastern Asia'),
#  'iran,-islamic-republic-of': ('Asia', 'Southern Asia'),
#  'iraq': ('Asia', 'Western Asia'),
#  'ireland': ('Europe', 'Northern Europe'),
#  'isle-of-man': ('Europe', 'Northern Europe'),
#  'israel': ('Asia', 'Western Asia'),
#  'italy': ('Europe', 'Southern Europe'),
#  'jamaica': ('Americas', 'Latin America and the Caribbean'),
#  'japan': ('Asia', 'Eastern Asia'),
#  'jersey': ('Europe', 'Northern Europe'),
#  'jordan': ('Asia', 'Western Asia'),
#  'kazakhstan': ('Asia', 'Central Asia'),
#  'kenya': ('Africa', 'Sub-Saharan Africa'),
#  'kiribati': ('Oceania', 'Micronesia'),
#  "korea,-democratic-people's-republic-of": ('Asia', 'Eastern Asia'),
#  'korea,-republic-of': ('Asia', 'Eastern Asia'),
#  'kuwait': ('Asia', 'Western Asia'),
#  'kyrgyzstan': ('Asia', 'Central Asia'),
#  "lao-people's-democratic-republic": ('Asia', 'South-eastern Asia'),
#  'latvia': ('Europe', 'Northern Europe'),
#  'lebanon': ('Asia', 'Western Asia'),
#  'lesotho': ('Africa', 'Sub-Saharan Africa'),
#  'liberia': ('Africa', 'Sub-Saharan Africa'),
#  'libya': ('Africa', 'Northern Africa'),
#  'liechtenstein': ('Europe', 'Western Europe'),
#  'lithuania': ('Europe', 'Northern Europe'),
#  'luxembourg': ('Europe', 'Western Europe'),
#  'macao': ('Asia', 'Eastern Asia'),
#  'madagascar': ('Africa', 'Sub-Saharan Africa'),
#  'malawi': ('Africa', 'Sub-Saharan Africa'),
#  'malaysia': ('Asia', 'South-eastern Asia'),
#  'maldives': ('Asia', 'Southern Asia'),
#  'mali': ('Africa', 'Sub-Saharan Africa'),
#  'malta': ('Europe', 'Southern Europe'),
#  'marshall-islands': ('Oceania', 'Micronesia'),
#  'martinique': ('Americas', 'Latin America and the Caribbean'),
#  'mauritania': ('Africa', 'Sub-Saharan Africa'),
#  'mauritius': ('Africa', 'Sub-Saharan Africa'),
#  'mayotte': ('Africa', 'Sub-Saharan Africa'),
#  'mexico': ('Americas', 'Latin America and the Caribbean'),
#  'micronesia,-federated-states-of': ('Oceania', 'Micronesia'),
#  'moldova,-republic-of': ('Europe', 'Eastern Europe'),
#  'monaco': ('Europe', 'Western Europe'),
#  'mongolia': ('Asia', 'Eastern Asia'),
#  'montenegro': ('Europe', 'Southern Europe'),
#  'montserrat': ('Americas', 'Latin America and the Caribbean'),
#  'morocco': ('Africa', 'Northern Africa'),
#  'mozambique': ('Africa', 'Sub-Saharan Africa'),
#  'myanmar': ('Asia', 'South-eastern Asia'),
#  'namibia': ('Africa', 'Sub-Saharan Africa'),
#  'nauru': ('Oceania', 'Micronesia'),
#  'nepal': ('Asia', 'Southern Asia'),
#  'netherlands,-kingdom-of-the': ('Europe', 'Western Europe'),
#  'new-caledonia': ('Oceania', 'Melanesia'),
#  'new-zealand': ('Oceania', 'Australia and New Zealand'),
#  'nicaragua': ('Americas', 'Latin America and the Caribbean'),
#  'niger': ('Africa', 'Sub-Saharan Africa'),
#  'nigeria': ('Africa', 'Sub-Saharan Africa'),
#  'niue': ('Oceania', 'Polynesia'),
#  'norfolk-island': ('Oceania', 'Australia and New Zealand'),
#  'north-macedonia': ('Europe', 'Southern Europe'),
#  'northern-mariana-islands': ('Oceania', 'Micronesia'),
#  'norway': ('Europe', 'Northern Europe'),
#  'oman': ('Asia', 'Western Asia'),
#  'pakistan': ('Asia', 'Southern Asia'),
#  'palau': ('Oceania', 'Micronesia'),
#  'palestine,-state-of': ('Asia', 'Western Asia'),
#  'panama': ('Americas', 'Latin America and the Caribbean'),
#  'papua-new-guinea': ('Oceania', 'Melanesia'),
#  'paraguay': ('Americas', 'Latin America and the Caribbean'),
#  'peru': ('Americas', 'Latin America and the Caribbean'),
#  'philippines': ('Asia', 'South-eastern Asia'),
#  'pitcairn': ('Oceania', 'Polynesia'),
#  'poland': ('Europe', 'Eastern Europe'),
#  'portugal': ('Europe', 'Southern Europe'),
#  'puerto-rico': ('Americas', 'Latin America and the Caribbean'),
#  'qatar': ('Asia', 'Western Asia'),
#  'réunion': ('Africa', 'Sub-Saharan Africa'),
#  'romania': ('Europe', 'Eastern Europe'),
#  'russian-federation': ('Europe', 'Eastern Europe'),
#  'rwanda': ('Africa', 'Sub-Saharan Africa'),
#  'saint-barthélemy': ('Americas', 'Latin America and the Caribbean'),
#  'saint-helena,-ascension-and-tristan-da-cunha': ('Africa',
#   'Sub-Saharan Africa'),
#  'saint-kitts-and-nevis': ('Americas', 'Latin America and the Caribbean'),
#  'saint-lucia': ('Americas', 'Latin America and the Caribbean'),
#  'saint-martin-(french-part)': ('Americas', 'Latin America and the Caribbean'),
#  'saint-pierre-and-miquelon': ('Americas', 'Northern America'),
#  'saint-vincent-and-the-grenadines': ('Americas',
#   'Latin America and the Caribbean'),
#  'samoa': ('Oceania', 'Polynesia'),
#  'san-marino': ('Europe', 'Southern Europe'),
#  'sao-tome-and-principe': ('Africa', 'Sub-Saharan Africa'),
#  'saudi-arabia': ('Asia', 'Western Asia'),
#  'senegal': ('Africa', 'Sub-Saharan Africa'),
#  'serbia': ('Europe', 'Southern Europe'),
#  'seychelles': ('Africa', 'Sub-Saharan Africa'),
#  'sierra-leone': ('Africa', 'Sub-Saharan Africa'),
#  'singapore': ('Asia', 'South-eastern Asia'),
#  'sint-maarten-(dutch-part)': ('Americas', 'Latin America and the Caribbean'),
#  'slovakia': ('Europe', 'Eastern Europe'),
#  'slovenia': ('Europe', 'Southern Europe'),
#  'solomon-islands': ('Oceania', 'Melanesia'),
#  'somalia': ('Africa', 'Sub-Saharan Africa'),
#  'south-africa': ('Africa', 'Sub-Saharan Africa'),
#  'south-georgia-and-the-south-sandwich-islands': ('Americas',
#   'Latin America and the Caribbean'),
#  'south-sudan': ('Africa', 'Sub-Saharan Africa'),
#  'spain': ('Europe', 'Southern Europe'),
#  'sri-lanka': ('Asia', 'Southern Asia'),
#  'sudan': ('Africa', 'Northern Africa'),
#  'suriname': ('Americas', 'Latin America and the Caribbean'),
#  'svalbard-and-jan-mayen': ('Europe', 'Northern Europe'),
#  'sweden': ('Europe', 'Northern Europe'),
#  'switzerland': ('Europe', 'Western Europe'),
#  'syrian-arab-republic': ('Asia', 'Western Asia'),
#  'taiwan,-province-of-china': (nan, nan),
#  'tajikistan': ('Asia', 'Central Asia'),
#  'tanzania,-united-republic-of': ('Africa', 'Sub-Saharan Africa'),
#  'thailand': ('Asia', 'South-eastern Asia'),
#  'timor-leste': ('Asia', 'South-eastern Asia'),
#  'togo': ('Africa', 'Sub-Saharan Africa'),
#  'tokelau': ('Oceania', 'Polynesia'),
#  'tonga': ('Oceania', 'Polynesia'),
#  'trinidad-and-tobago': ('Americas', 'Latin America and the Caribbean'),
#  'tunisia': ('Africa', 'Northern Africa'),
#  'türkiye': ('Asia', 'Western Asia'),
#  'turkmenistan': ('Asia', 'Central Asia'),
#  'turks-and-caicos-islands': ('Americas', 'Latin America and the Caribbean'),
#  'tuvalu': ('Oceania', 'Polynesia'),
#  'uganda': ('Africa', 'Sub-Saharan Africa'),
#  'ukraine': ('Europe', 'Eastern Europe'),
#  'united-arab-emirates': ('Asia', 'Western Asia'),
#  'united-kingdom-of-great-britain-and-northern-ireland': ('Europe',
#   'Northern Europe'),
#  'united-states-of-america': ('Americas', 'Northern America'),
#  'united-states-minor-outlying-islands': ('Oceania', 'Micronesia'),
#  'uruguay': ('Americas', 'Latin America and the Caribbean'),
#  'uzbekistan': ('Asia', 'Central Asia'),
#  'vanuatu': ('Oceania', 'Melanesia'),
#  'venezuela,-bolivarian-republic-of': ('Americas',
#   'Latin America and the Caribbean'),
#  'viet-nam': ('Asia', 'South-eastern Asia'),
#  'virgin-islands-(british)': ('Americas', 'Latin America and the Caribbean'),
#  'virgin-islands-(u.s.)': ('Americas', 'Latin America and the Caribbean'),
#  'wallis-and-futuna': ('Oceania', 'Polynesia'),
#  'western-sahara': ('Africa', 'Northern Africa'),
#  'yemen': ('Asia', 'Western Asia'),
#  'zambia': ('Africa', 'Sub-Saharan Africa'),
#  'zimbabwe': ('Africa', 'Sub-Saharan Africa')}

# %% [markdown]
# **We now have the mapping from country to (region/subregion)**

# %% [markdown]
# ## Preprocess OpenFoodFacts dataset

# %%
# Read columns, drop NaN values
df = pd.read_csv(
    "../../en.openfoodfacts.org.products.csv",
    usecols=["origins", "origins_tags", "countries", "countries_tags"],
    sep="\t",
    on_bad_lines='skip'
).dropna(subset=["countries"])  # Drop rows with NaN in countries
# Out:
# /tmp/ipykernel_14586/2639269984.py:2: DtypeWarning: Columns (23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
df.head()
# Out:
#             origins            origins_tags  \
# 0               NaN                     NaN
# 1            Canada               en:canada
# 2               NaN                     NaN
# 3  Peru,Netherlands  en:netherlands,en:peru
# 4               NaN                     NaN
#
#                                  countries               countries_tags
# 0  Vereinigte Staaten von Amerika, Germany  en:germany,en:united-states
# 1                                   Canada                    en:canada
# 2                                       GR                    en:greece
# 3                                       CZ            en:czech-republic
# 4                                   France                    en:france

# %%
# Function to extract countries from tags
def extract_countries(tags_str):
    # Split tags, filter those starting with 'en:', remove 'en:' prefix
    countries = [tag.split(':')[1] for tag in str(tags_str).split(',') if tag.startswith('en:')]
    return countries

# %%
# Function to map countries to regions
def map_to_regions(countries):
    return [country_to_region.get(country, 'Other')[0] for country in countries]

# %%
# Process countries
df['processed_countries'] = df['countries_tags'].apply(extract_countries)
df['regions'] = df['processed_countries'].apply(map_to_regions)

# %%
country_to_region["united-states-of-america"]
# Out:
# ('Americas', 'Northern America')

# %%
df.head(n = 10)
# Out:
#             origins            origins_tags  \
# 0               NaN                     NaN
# 1            Canada               en:canada
# 2               NaN                     NaN
# 3  Peru,Netherlands  en:netherlands,en:peru
# 4               NaN                     NaN
# 5               NaN                     NaN
# 6               NaN                     NaN
# 7               NaN                     NaN
# 8               NaN                     NaN
# 9               NaN                     NaN
#
#                                  countries               countries_tags  \
# 0  Vereinigte Staaten von Amerika, Germany  en:germany,en:united-states
# 1                                   Canada                    en:canada
# 2                                       GR                    en:greece
# 3                                       CZ            en:czech-republic
# 4                                   France                    en:france
# 5                              Inde, en:sn          en:india,en:senegal
# 6                                 en:Spain                     en:spain
# 7                                       US             en:united-states
# 8                                   España                     en:spain
# 9                        en:germany, World          en:germany,en:world
#
#         processed_countries         regions
# 0  [germany, united-states]     [Europe, O]
# 1                  [canada]      [Americas]
# 2                  [greece]        [Europe]
# 3          [czech-republic]             [O]
# 4                  [france]        [Europe]
# 5          [india, senegal]  [Asia, Africa]
# 6                   [spain]        [Europe]
# 7           [united-states]             [O]
# 8                   [spain]        [Europe]
# 9          [germany, world]     [Europe, O]

# %%
# Explode the dataframe to create separate rows for each region
df_exploded = df.explode('regions')

# %%
df_exploded.head(n=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_exploded.head(n=20)
#
# NameError: name 'df_exploded' is not defined

# %%
# Group and count regions
region_counts = df_exploded['regions'].value_counts().reset_index()
region_counts.columns = ['region', 'count']

# %%
region_counts
# Out:
#           region    count
# 0          Other  2718417
# 1         Europe   601468
# 2  North America   346484
# 3        Oceania     7643
# 4  South America     7230
# 5           Asia     4440

# %%
cols = pd.read_csv(
    "../../en.openfoodfacts.org.products.csv",
    sep="\t",
    on_bad_lines='skip',
    nrows=1
).columns.tolist()

i, MOD = 0, 4
for col in cols:
    print(f"{col:<60}", end="")
    if i == MOD - 1:
        print()
    i = (i + 1) % MOD
# Out:
# code                                                        url                                                         creator                                                     created_t
# created_datetime                                            last_modified_t                                             last_modified_datetime                                      last_modified_by
# last_updated_t                                              last_updated_datetime                                       product_name                                                abbreviated_product_name
# generic_name                                                quantity                                                    packaging                                                   packaging_tags
# packaging_en                                                packaging_text                                              brands                                                      brands_tags
# categories                                                  categories_tags                                             categories_en                                               origins
# origins_tags                                                origins_en                                                  manufacturing_places                                        manufacturing_places_tags
# labels                                                      labels_tags                                                 labels_en                                                   emb_codes
# emb_codes_tags                                              first_packaging_code_geo                                    cities                                                      cities_tags
# purchase_places                                             stores                                                      countries                                                   countries_tags
# countries_en                                                ingredients_text                                            ingredients_tags                                            ingredients_analysis_tags
# allergens                                                   allergens_en                                                traces                                                      traces_tags
# traces_en                                                   serving_size                                                serving_quantity                                            no_nutrition_data
# additives_n                                                 additives                                                   additives_tags                                              additives_en
# nutriscore_score                                            nutriscore_grade                                            nova_group                                                  pnns_groups_1
# pnns_groups_2                                               food_groups                                                 food_groups_tags                                            food_groups_en
# states                                                      states_tags                                                 states_en                                                   brand_owner
# ecoscore_score                                              ecoscore_grade                                              nutrient_levels_tags                                        product_quantity
# owner                                                       data_quality_errors_tags                                    unique_scans_n                                              popularity_tags
# completeness                                                last_image_t                                                last_image_datetime                                         main_category
# main_category_en                                            image_url                                                   image_small_url                                             image_ingredients_url
# image_ingredients_small_url                                 image_nutrition_url                                         image_nutrition_small_url                                   energy-kj_100g
# energy-kcal_100g                                            energy_100g                                                 energy-from-fat_100g                                        fat_100g
# saturated-fat_100g                                          butyric-acid_100g                                           caproic-acid_100g                                           caprylic-acid_100g
# capric-acid_100g                                            lauric-acid_100g                                            myristic-acid_100g                                          palmitic-acid_100g
# stearic-acid_100g                                           arachidic-acid_100g                                         behenic-acid_100g                                           lignoceric-acid_100g
# cerotic-acid_100g                                           montanic-acid_100g                                          melissic-acid_100g                                          unsaturated-fat_100g
# monounsaturated-fat_100g                                    omega-9-fat_100g                                            polyunsaturated-fat_100g                                    omega-3-fat_100g
# omega-6-fat_100g                                            alpha-linolenic-acid_100g                                   eicosapentaenoic-acid_100g                                  docosahexaenoic-acid_100g
# linoleic-acid_100g                                          arachidonic-acid_100g                                       gamma-linolenic-acid_100g                                   dihomo-gamma-linolenic-acid_100g
# oleic-acid_100g                                             elaidic-acid_100g                                           gondoic-acid_100g                                           mead-acid_100g
# erucic-acid_100g                                            nervonic-acid_100g                                          trans-fat_100g                                              cholesterol_100g
# carbohydrates_100g                                          sugars_100g                                                 added-sugars_100g                                           sucrose_100g
# glucose_100g                                                fructose_100g                                               lactose_100g                                                maltose_100g
# maltodextrins_100g                                          starch_100g                                                 polyols_100g                                                erythritol_100g
# fiber_100g                                                  soluble-fiber_100g                                          insoluble-fiber_100g                                        proteins_100g
# casein_100g                                                 serum-proteins_100g                                         nucleotides_100g                                            salt_100g
# added-salt_100g                                             sodium_100g                                                 alcohol_100g                                                vitamin-a_100g
# beta-carotene_100g                                          vitamin-d_100g                                              vitamin-e_100g                                              vitamin-k_100g
# vitamin-c_100g                                              vitamin-b1_100g                                             vitamin-b2_100g                                             vitamin-pp_100g
# vitamin-b6_100g                                             vitamin-b9_100g                                             folates_100g                                                vitamin-b12_100g
# biotin_100g                                                 pantothenic-acid_100g                                       silica_100g                                                 bicarbonate_100g
# potassium_100g                                              chloride_100g                                               calcium_100g                                                phosphorus_100g
# iron_100g                                                   magnesium_100g                                              zinc_100g                                                   copper_100g
# manganese_100g                                              fluoride_100g                                               selenium_100g                                               chromium_100g
# molybdenum_100g                                             iodine_100g                                                 caffeine_100g                                               taurine_100g
# ph_100g                                                     fruits-vegetables-nuts_100g                                 fruits-vegetables-nuts-dried_100g                           fruits-vegetables-nuts-estimate_100g
# fruits-vegetables-nuts-estimate-from-ingredients_100g       collagen-meat-protein-ratio_100g                            cocoa_100g                                                  chlorophyl_100g
# carbon-footprint_100g                                       carbon-footprint-from-meat-or-fish_100g                     nutrition-score-fr_100g                                     nutrition-score-uk_100g
# glycemic-index_100g                                         water-hardness_100g                                         choline_100g                                                phylloquinone_100g
# beta-glucan_100g                                            inositol_100g                                               carnitine_100g                                              sulphate_100g
# nitrate_100g                                                acidity_100g

# %%
# Read columns, drop NaN values
df = pd.read_csv(
    "../../en.openfoodfacts.org.products.csv",
    sep="\t",
    usecols=["product_name", "origins", "countries"],
    on_bad_lines='skip',
    nrows=10
).dropna(subset=["countries"])  # Drop rows with NaN in countries

# %%
df
# Out:
#                        product_name           origins  \
# 0                             Filet               NaN
# 1                 Poudre de grillon            Canada
# 2  Feuchtes Toilettentuch - Kamille               NaN
# 3             Almond Dark Chocolate  Peru,Netherlands
# 4                        Bio inulin               NaN
# 5                    Mac and cheese               NaN
# 6                               NaN               NaN
# 7                        After burn               NaN
# 8                  Flohsamenschalen               NaN
# 9        Protein Plant Powered Wrap               NaN
#
#                                  countries
# 0  Vereinigte Staaten von Amerika, Germany
# 1                                   Canada
# 2                                       GR
# 3                                       CZ
# 4                                   France
# 5                              Inde, en:sn
# 6                                 en:Spain
# 7                                       US
# 8                                   España
# 9                        en:germany, World
